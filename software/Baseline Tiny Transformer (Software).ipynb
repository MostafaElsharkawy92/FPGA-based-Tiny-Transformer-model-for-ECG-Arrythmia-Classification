# %% [markdown]
# # **Tiny Transformer Model (Baseline)**

# %%
# !pip install wfdb

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import h5py
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import wfdb
import random
import scipy.signal
from scipy import signal
from collections import Counter
import json
import pandas as pd

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================
class Config:
    # Model hyperparameters
    num_heads = 8
    hidden_size = 2
    embedding = 16
    mlp_dim = 128
    kernel = 3
    emb_depth = 1
    transformer_layers = 1
    half_window = 99
    batch_size = 128

    # Training parameters
    learning_rate = 2e-3
    epochs = 100
    patience = 25
    random_seed = 42

    # Data paths
    data_path = 'physionet.org/files/mitdb/1.0.0/'
    splits_file = 'consistent_data_splits.npz'
    baseline_weights = 'baseline_ecg_transformer.weights.h5'
    baseline_results = 'baseline_results.json'

config = Config()

# Set all random seeds for reproducibility
np.random.seed(config.random_seed)
tf.random.set_seed(config.random_seed)
random.seed(config.random_seed)

# %%
                                                                                                                                                                                                                      # =============================================================================
# DATA PREPROCESSING
# =============================================================================
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = signal.butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = signal.lfilter(b, a, data)
    return y

def preprocess_ecg(signal_data, fs=360):
    """Preprocess ECG signal: bandpass filter 0.5-40 Hz + normalization"""
    filtered = butter_bandpass_filter(signal_data, 0.5, 40.0, fs, order=5)
    normalized = (filtered - np.mean(filtered)) / (np.std(filtered) + 1e-8)
    return normalized

def extract_beats(record_path, classes_to_use=None):
    """Extract beats from a single MIT-BIH record with proper AAMI mapping"""
    if classes_to_use is None:
        classes_to_use = config.class_types

    # MIT-BIH to AAMI symbol mapping (AAMI EC57 standard)
    mit_bih_to_aami = {
        'N': 'N', 'L': 'N', 'R': 'N', 'e': 'N', 'j': 'N', '.': 'N',
        'A': 'S', 'a': 'S', 'J': 'S', 'S': 'S',
        'V': 'V', 'E': 'V',
        'F': 'F',
        '/': 'Q', 'f': 'Q', 'Q': 'Q', '?': 'Q',
    }

    try:
        record = wfdb.rdrecord(record_path)
        annotation = wfdb.rdann(record_path, 'atr')
    except Exception as e:
        print(f"Error reading {record_path}: {e}")
        return [], [], []

    signal_data = record.p_signal[:, 0]
    fs = record.fs
    signal_data = preprocess_ecg(signal_data, fs)

    beats, labels, rr_intervals = [], [], []
    r_peaks = annotation.sample
    symbols = annotation.symbol

    for i in range(1, len(r_peaks) - 1):
        mit_symbol = symbols[i]
        if mit_symbol in mit_bih_to_aami:
            aami_class = mit_bih_to_aami[mit_symbol]
            if aami_class in classes_to_use:
                start = r_peaks[i] - config.half_window
                end = r_peaks[i] + config.half_window

                if start < 0 or end >= len(signal_data):
                    continue

                beat = signal_data[start:end]

                # Calculate RR intervals (normalized)
                pre_rr = (r_peaks[i] - r_peaks[i-1]) / fs
                post_rr = (r_peaks[i+1] - r_peaks[i]) / fs
                pre_rr = np.clip(pre_rr, 0, 2)
                post_rr = np.clip(post_rr, 0, 2)

                beats.append(beat)
                labels.append(aami_class)
                rr_intervals.append([pre_rr, post_rr])

    return beats, labels, rr_intervals

def load_mit_bih_data():
    """Load complete MIT-BIH dataset"""
    # Standard DS1 and DS2 record splits from AAMI
    ds1_records = ['101', '106', '108', '109', '112', '114', '115', '116',
                   '118', '119', '122', '124', '201', '203', '205', '207',
                   '208', '209', '215', '220', '223', '230']
    ds2_records = ['100', '103', '105', '111', '113', '117', '121', '123',
                   '200', '202', '210', '212', '213', '214', '219', '221',
                   '222', '228', '231', '232', '233', '234']
    all_records = ds1_records + ds2_records

    all_beats = []
    all_labels = []
    all_rr_intervals = []

    print(f"Loading MIT-BIH data from {config.data_path}...")
    for record in all_records:
        try:
            record_path = os.path.join(config.data_path, record)
            beats, labels, rr_intervals = extract_beats(record_path)
            all_beats.extend(beats)
            all_labels.extend(labels)
            all_rr_intervals.extend(rr_intervals)
            print(f"  ✓ Record {record}: {len(beats)} beats")
        except Exception as e:
            print(f"  ✗ Record {record}: {e}")

    # Convert to numpy arrays
    all_beats = np.array(all_beats)
    all_rr_intervals = np.array(all_rr_intervals)

    # Convert labels to integers
    label_map = {label: idx for idx, label in enumerate(config.class_types)}
    all_labels_int = np.array([label_map[label] for label in all_labels])

    print(f"\nTotal beats loaded: {len(all_beats)}")
    print(f"Label distribution: {Counter(all_labels)}")

    return all_beats, all_labels_int, all_rr_intervals

def create_consistent_data_splits(force_recreate=False):
    """Create train/val/test splits"""
    if os.path.exists(config.splits_file) and not force_recreate:
        print(f"Loading existing data splits from {config.splits_file}")
        data = np.load(config.splits_file)
        return (data['X_train'], data['X_val'], data['X_test'],
                data['y_train'], data['y_val'], data['y_test'],
                data['RR_train'], data['RR_val'], data['RR_test'])

    print("Creating data splits...")

    # Load complete dataset
    beats, labels, rr_intervals = load_mit_bih_data()
    if len(beats) == 0:
        raise ValueError("No data loaded! Check your data path.")

    # Step 1: 70% train, 30% temp (validation + test)
    X_train, X_temp, y_train, y_temp, RR_train, RR_temp = train_test_split(
        beats, labels, rr_intervals,
        test_size=0.30,
        random_state=config.random_seed,
        stratify=labels
    )

    # Step 2: Split temp into 10% validation, 20% test
    X_val, X_test, y_val, y_test, RR_val, RR_test = train_test_split(
        X_temp, y_temp, RR_temp,
        test_size=2/3,
        random_state=config.random_seed,
        stratify=y_temp
    )

    # Print split distributions
    def print_split_info(y, split_name):
        unique, counts = np.unique(y, return_counts=True)
        total = len(y)
        print(f"\n{split_name} ({total} samples, {total/len(labels)*100:.1f}%):")
        for class_idx, count in zip(unique, counts):
            class_name = config.class_types[class_idx]
            percentage = (count / total) * 100
            print(f"  {class_name}: {count:5d} ({percentage:5.1f}%)")

    print_split_info(y_train, "Training")
    print_split_info(y_val, "Validation")
    print_split_info(y_test, "Test")

    # Save splits for consistency across experiments
    np.savez(config.splits_file,
             X_train=X_train, X_val=X_val, X_test=X_test,
             y_train=y_train, y_val=y_val, y_test=y_test,
             RR_train=RR_train, RR_val=RR_val, RR_test=RR_test)

    print(f"Data splits saved to {config.splits_file}")

    return X_train, X_val, X_test, y_train, y_val, y_test, RR_train, RR_val, RR_test

# %%
# =============================================================================
# MODEL COMPONENTS
# =============================================================================
def generate_patch_conv_orgPaper_f(embedding, inputs):
    patches = layers.Conv2D(filters=embedding, kernel_size=[config.kernel,1],
                           strides=[config.kernel,1], padding='valid')(inputs)
    for _ in range(config.emb_depth - 1):
        patches = layers.BatchNormalization()(patches)
        patches = layers.Conv2D(filters=embedding, kernel_size=[config.kernel,1],
                               strides=[config.kernel,1], padding='valid')(patches)

    row_axis, col_axis = (1, 2)
    seq_len = (patches.shape[row_axis]) * (patches.shape[col_axis])
    x = layers.Reshape((seq_len, embedding))(patches)
    return x

class AddPositionEmbs(layers.Layer):
    def __init__(self, posemb_init=None, **kwargs):
        super().__init__(**kwargs)
        self.posemb_init = posemb_init

    def build(self, inputs_shape):
        pos_emb_shape = (1, inputs_shape[1], inputs_shape[2])
        self.pos_embedding = self.add_weight(
            name='pos_embedding',
            shape=pos_emb_shape,
            initializer=self.posemb_init,
            trainable=True
        )

    def call(self, inputs, inputs_positions=None):
        pos_embedding = tf.cast(self.pos_embedding, inputs.dtype)
        return inputs + pos_embedding

def mlp_block_f(mlp_dim, inputs):
    x = layers.Dense(units=mlp_dim, activation=tf.nn.gelu)(inputs)
    x = layers.Dropout(rate=0.1)(x)
    x = layers.Dense(units=inputs.shape[-1], activation=tf.nn.gelu)(x)
    x = layers.Dropout(rate=0.1)(x)
    return x

def BaselineEncoder1Dblock(num_heads, mlp_dim, inputs):
    """Standard transformer block with fixed multi-head attention"""
    x = layers.LayerNormalization(dtype=inputs.dtype)(inputs)
    x = layers.MultiHeadAttention(
        num_heads=num_heads,
        key_dim=config.hidden_size,
        dropout=0.1
    )(x, x)
    x = layers.Add()([x, inputs])

    y = layers.LayerNormalization(dtype=x.dtype)(x)
    y = mlp_block_f(mlp_dim, y)
    y_1 = layers.Add()([y, x])
    return y_1

def build_baseline_ViT():
    """Build baseline Vision Transformer (standard attention)"""
    inputs = layers.Input(shape=(198,1,1), name='x1')
    RR_feat = layers.Input(shape=(2,), name='x2')

    patches = generate_patch_conv_orgPaper_f(config.embedding, inputs)
    x = AddPositionEmbs(
        posemb_init=tf.keras.initializers.RandomNormal(stddev=0.02),
        name='posembed_input'
    )(patches)
    x = layers.Dropout(rate=0.2)(x)

    x = BaselineEncoder1Dblock(config.num_heads, config.mlp_dim, x)
    encoded = layers.LayerNormalization(name='encoder_norm')(x)
    im_representation = layers.GlobalAveragePooling1D()(encoded)

    emb_RR = layers.Dense(units=2, use_bias=False)(RR_feat)
    im_representation = layers.Concatenate()([im_representation, emb_RR])

    logits = layers.Dense(
        units=len(config.class_types),
        name='head',
        kernel_initializer=tf.keras.initializers.zeros()
    )(im_representation)

    model = tf.keras.Model(inputs=[inputs, RR_feat], outputs=logits)
    return model

# %%
# =============================================================================
# DATASET CREATION
# =============================================================================
def create_datasets(X_train, RR_train, y_train, X_val, RR_val, y_val, batch_size):
    """Create TensorFlow datasets for training"""
    autotune = tf.data.AUTOTUNE

    # Reshape for Conv2D
    X_train = X_train.reshape(-1, 198, 1, 1)
    X_val = X_val.reshape(-1, 198, 1, 1)

    # Convert to categorical
    y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=len(config.class_types))
    y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=len(config.class_types))

    # Training dataset
    train_data = tf.data.Dataset.from_tensor_slices(X_train)
    train_RR = tf.data.Dataset.from_tensor_slices(RR_train)
    train_labels = tf.data.Dataset.from_tensor_slices(y_train_cat)

    X_train_ds = tf.data.Dataset.zip((train_data, train_RR)).map(
        lambda x1, x2: {'x1': x1, 'x2': x2}
    )
    train_ds = tf.data.Dataset.zip((X_train_ds, train_labels))
    train_ds = (train_ds.shuffle(10000, seed=config.random_seed)
                .batch(batch_size)
                .prefetch(autotune))

    # Validation dataset
    val_data = tf.data.Dataset.from_tensor_slices(X_val)
    val_RR = tf.data.Dataset.from_tensor_slices(RR_val)
    val_labels = tf.data.Dataset.from_tensor_slices(y_val_cat)

    X_val_ds = tf.data.Dataset.zip((val_data, val_RR)).map(
        lambda x1, x2: {'x1': x1, 'x2': x2}
    )
    val_ds = tf.data.Dataset.zip((X_val_ds, val_labels))
    val_ds = (val_ds.batch(batch_size)
              .prefetch(autotune))

    return train_ds, val_ds

def create_test_dataset(X_test, RR_test, y_test, batch_size):
    """Create test dataset"""
    X_test = X_test.reshape(-1, 198, 1, 1)
    y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes=len(config.class_types))

    test_data = tf.data.Dataset.from_tensor_slices(X_test)
    test_RR = tf.data.Dataset.from_tensor_slices(RR_test)
    test_labels = tf.data.Dataset.from_tensor_slices(y_test_cat)

    X_test_ds = tf.data.Dataset.zip((test_data, test_RR)).map(
        lambda x1, x2: {'x1': x1, 'x2': x2}
    )
    test_ds = tf.data.Dataset.zip((X_test_ds, test_labels))
    test_ds = test_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return test_ds

# %%
# =============================================================================
# TRAINING FUNCTION
# =============================================================================
def train_baseline_model(model, train_ds, val_ds, weights_path):
    """Train baseline model"""
    print(f"\n Training Baseline ECG Transformer...")

    # Compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=['accuracy']
    )

    # Callbacks
    checkpoint = ModelCheckpoint(
        weights_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=config.patience,
        restore_best_weights=True,
        mode='max',
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=10,
        min_lr=1e-7,
        verbose=1
    )

    # Train model
    history = model.fit(
        train_ds,
        epochs=config.epochs,
        validation_data=val_ds,
        callbacks=[checkpoint, early_stopping, reduce_lr],
        verbose=1
    )

    print(f"✅ Baseline training completed!")
    print(f"Best validation accuracy: {max(history.history['val_accuracy']):.4f}")

    return history

# %%
# =============================================================================
# EVALUATION FUNCTION
# =============================================================================
def evaluate_baseline_model(model, test_ds, y_test):
    """Evaluate baseline model comprehensively"""
    print(f"\n Evaluating Baseline Model...")

    # Compile model for evaluation
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=config.learning_rate),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=['accuracy']
    )

    # Collect predictions
    logits_list = []
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=True)

    print("Running inference...")
    for batch_idx, batch in enumerate(test_ds):
        inputs_dict, labels_onehot = batch

        # Forward pass
        logits = model(inputs_dict, training=False)
        logits_np = logits.numpy()
        logits_list.append(logits_np)

        # Calculate metrics
        bsize = logits_np.shape[0]
        total_samples += bsize

        batch_loss = loss_fn(labels_onehot, logits).numpy()
        total_loss += batch_loss * bsize

        preds_int = np.argmax(logits_np, axis=1)
        true_int = np.argmax(labels_onehot.numpy(), axis=1)
        total_correct += np.sum(preds_int == true_int)

        if (batch_idx + 1) % 10 == 0:
            print(f"  Processed {batch_idx + 1} batches...")

    # Final metrics
    test_loss = total_loss / total_samples
    test_accuracy = total_correct / total_samples

    # Get predictions and probabilities
    all_logits = np.concatenate(logits_list, axis=0)
    y_pred_probs = tf.nn.softmax(all_logits, axis=1).numpy()
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Detailed metrics with zero_division parameter
    precision_macro = precision_score(y_test, y_pred, average='macro', zero_division=0)
    recall_macro = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)

    precision_weighted = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall_weighted = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)

    print(f"\n Baseline Model Test Results:")
    print(f"Test Loss:           {test_loss:.4f}")
    print(f"Test Accuracy:       {test_accuracy:.4f}")
    print(f"Precision (macro):   {precision_macro:.4f}")
    print(f"Recall (macro):      {recall_macro:.4f}")
    print(f"F1-Score (macro):    {f1_macro:.4f}")
    print(f"Precision (weighted): {precision_weighted:.4f}")
    print(f"Recall (weighted):   {recall_weighted:.4f}")
    print(f"F1-Score (weighted): {f1_weighted:.4f}")

    # Classification report
    print(f"\n Classification Report:")
    print(classification_report(y_test, y_pred, target_names=config.class_types, digits=4))

    results = {
        'model_name': 'Baseline',
        'test_accuracy': float(test_accuracy),
        'test_loss': float(test_loss),
        'precision_macro': float(precision_macro),
        'recall_macro': float(recall_macro),
        'f1_macro': float(f1_macro),
        'precision_weighted': float(precision_weighted),
        'recall_weighted': float(recall_weighted),
        'f1_weighted': float(f1_weighted),
        'predictions': y_pred.tolist(),
        'true_labels': y_test.tolist()
    }

    return results

# %%
# =============================================================================
# VISUALIZATION FUNCTIONS
# =============================================================================
def plot_baseline_training_history(history, save_path='baseline_training_history.png'):
    """Plot baseline training history"""
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))

    # Loss plots
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].set_title('Training Loss')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    axes[0, 1].plot(history.history['val_loss'], label='Val Loss', color='orange')
    axes[0, 1].set_title('Validation Loss')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Accuracy plots
    axes[1, 0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[1, 0].set_title('Training Accuracy')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    axes[1, 0].grid(True)

    axes[1, 1].plot(history.history['val_accuracy'], label='Val Accuracy', color='orange')
    axes[1, 1].set_title('Validation Accuracy')
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Accuracy')
    axes[1, 1].legend()
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

def plot_baseline_confusion_matrix(results, save_path='baseline_confusion_matrix.png'):
    """Plot confusion matrix for baseline model"""
    y_true = results['true_labels']
    y_pred = results['predictions']

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
               xticklabels=config.class_types, yticklabels=config.class_types)
    plt.title(f'Baseline Model Confusion Matrix\nAccuracy: {results["test_accuracy"]:.4f}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

def download_mitbih_data():
    """Download MIT-BIH dataset if not present"""
    if not os.path.exists(config.data_path):
        print("📥 Downloading MIT-BIH Arrhythmia Database...")
        os.system('wget -r -N -c -np https://physionet.org/files/mitdb/1.0.0/')
        print("✅ Download completed!")
    else:
        print("✅ MIT-BIH data already exists.")

# %%
# =============================================================================
# MAIN EXECUTION
# =============================================================================
def main():
    """Main execution for baseline model"""
    print(" BASELINE ECG Transformer - Training & Evaluation")
    print("=" * 60)

    # Setup GPU if available
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            print(f" Found {len(gpus)} GPU(s), memory growth enabled")
        except RuntimeError as e:
            print(f"GPU setup error: {e}")
    else:
        print(" No GPU found, running on CPU")

    # Download data if needed
    download_mitbih_data()

    # Create consistent data splits
    print("\n Creating/Loading data splits...")
    X_train, X_val, X_test, y_train, y_val, y_test, RR_train, RR_val, RR_test = create_consistent_data_splits()

    # Calculate class weights
    class_weights = class_weight.compute_class_weight(
        'balanced', classes=np.unique(y_train), y=y_train
    )
    class_weight_dict = dict(enumerate(class_weights))
    print(f"Class weights: {class_weight_dict}")

    # Create datasets
    train_ds, val_ds = create_datasets(X_train, RR_train, y_train, X_val, RR_val, y_val, config.batch_size)
    test_ds = create_test_dataset(X_test, RR_test, y_test, config.batch_size)

    # Build and train baseline model
    print("\n🏗️  Building Baseline Model...")
    baseline_model = build_baseline_ViT()
    print(f"Baseline model parameters: {baseline_model.count_params():,}")

    # Check if model already exists
    if os.path.exists(config.baseline_weights):
        print(f"\n Found existing baseline weights: {config.baseline_weights}")
        choice = input("Do you want to (1) Retrain, (2) Load existing, or (3) Skip training? [1/2/3]: ")

        if choice == '2':
            print(" Loading existing baseline weights...")
            baseline_model.load_weights(config.baseline_weights)
            history = None
        elif choice == '3':
            print("Skipping baseline training...")
            return
        else:
            print(" Retraining baseline model...")
            history = train_baseline_model(baseline_model, train_ds, val_ds, config.baseline_weights)
            baseline_model.load_weights(config.baseline_weights)
    else:
        history = train_baseline_model(baseline_model, train_ds, val_ds, config.baseline_weights)
        baseline_model.load_weights(config.baseline_weights)

    # Evaluate baseline model
    print("\n Evaluating Baseline Model...")
    results = evaluate_baseline_model(baseline_model, test_ds, y_test)

    # Save results
    with open(config.baseline_results, 'w') as f:
        json.dump(results, f, indent=2)
    print(f" Results saved to {config.baseline_results}")

    # Generate visualizations
    if history is not None:
        print("\n Generating training history plot...")
        plot_baseline_training_history(history)

    print(" Generating confusion matrix...")
    plot_baseline_confusion_matrix(results)

    # Final summary
    print("\n" + "="*60)
    print("🎉 BASELINE MODEL SUMMARY")
    print("="*60)
    print(f"Test Accuracy:     {results['test_accuracy']:.4f}")
    print(f"Test Loss:         {results['test_loss']:.4f}")
    print(f"F1-Score (macro):  {results['f1_macro']:.4f}")
    print(f"F1-Score (weighted): {results['f1_weighted']:.4f}")

    print(f"\n Files Generated:")
    print(f"  - {config.baseline_weights} (model weights)")
    print(f"  - {config.baseline_results} (detailed results)")
    print(f"  - {config.splits_file} (data splits for consistency)")
    print(f"  - baseline_training_history.png")
    print(f"  - baseline_confusion_matrix.png")

    print(f"\n Baseline model training and evaluation completed!")
    return results

if __name__ == "__main__":
    # Install required package if needed
    try:
        import wfdb
    except ImportError:
        print("Installing wfdb package...")
        os.system('pip install wfdb')
        import wfdb

    # Run baseline pipeline
    results = main()
# Out:
# 🚀 BASELINE ECG Transformer - Training & Evaluation
# ============================================================
# ✅ Found 1 GPU(s), memory growth enabled
# ✅ MIT-BIH data already exists.
#
# 📊 Creating/Loading data splits...
# Loading existing data splits from consistent_data_splits.npz
# Class weights: {0: np.float64(0.22354713868798376), 1: np.float64(7.246375321336761), 2: np.float64(2.872849571952711), 3: np.float64(25.123351158645278), 4: np.float64(1281.290909090909)}
#
# 🏗️  Building Baseline Model...
# Baseline model parameters: 6,643
#
# 🚀 Training Baseline ECG Transformer...
# Epoch 1/100
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9034 - loss: 0.5197
# Epoch 1: val_accuracy improved from -inf to 0.94547, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.9034 - loss: 0.5194 - val_accuracy: 0.9455 - val_loss: 0.1935 - learning_rate: 0.0020
# Epoch 2/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9464 - loss: 0.1919
# Epoch 2: val_accuracy improved from 0.94547 to 0.96374, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9465 - loss: 0.1916 - val_accuracy: 0.9637 - val_loss: 0.1397 - learning_rate: 0.0020
# Epoch 3/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9643 - loss: 0.1375
# Epoch 3: val_accuracy improved from 0.96374 to 0.96960, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9643 - loss: 0.1373 - val_accuracy: 0.9696 - val_loss: 0.1097 - learning_rate: 0.0020
# Epoch 4/100
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.1124
# Epoch 4: val_accuracy improved from 0.96960 to 0.97378, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9682 - loss: 0.1124 - val_accuracy: 0.9738 - val_loss: 0.0917 - learning_rate: 0.0020
# Epoch 5/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9713 - loss: 0.0997
# Epoch 5: val_accuracy improved from 0.97378 to 0.97835, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9713 - loss: 0.0996 - val_accuracy: 0.9783 - val_loss: 0.0781 - learning_rate: 0.0020
# Epoch 6/100
# 539/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9739 - loss: 0.0899
# Epoch 6: val_accuracy did not improve from 0.97835
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9739 - loss: 0.0899 - val_accuracy: 0.9753 - val_loss: 0.0827 - learning_rate: 0.0020
# Epoch 7/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9749 - loss: 0.0865
# Epoch 7: val_accuracy improved from 0.97835 to 0.97854, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9749 - loss: 0.0865 - val_accuracy: 0.9785 - val_loss: 0.0758 - learning_rate: 0.0020
# Epoch 8/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9762 - loss: 0.0830
# Epoch 8: val_accuracy did not improve from 0.97854
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9762 - loss: 0.0830 - val_accuracy: 0.9776 - val_loss: 0.0734 - learning_rate: 0.0020
# Epoch 9/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9753 - loss: 0.0831
# Epoch 9: val_accuracy improved from 0.97854 to 0.98073, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9753 - loss: 0.0831 - val_accuracy: 0.9807 - val_loss: 0.0664 - learning_rate: 0.0020
# Epoch 10/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0776
# Epoch 10: val_accuracy did not improve from 0.98073
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9761 - loss: 0.0776 - val_accuracy: 0.9800 - val_loss: 0.0673 - learning_rate: 0.0020
# Epoch 11/100
# 542/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9781 - loss: 0.0758
# Epoch 11: val_accuracy did not improve from 0.98073
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9781 - loss: 0.0758 - val_accuracy: 0.9798 - val_loss: 0.0675 - learning_rate: 0.0020
# Epoch 12/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0753
# Epoch 12: val_accuracy did not improve from 0.98073
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9782 - loss: 0.0753 - val_accuracy: 0.9777 - val_loss: 0.0717 - learning_rate: 0.0020
# Epoch 13/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0750
# Epoch 13: val_accuracy improved from 0.98073 to 0.98242, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9780 - loss: 0.0750 - val_accuracy: 0.9824 - val_loss: 0.0613 - learning_rate: 0.0020
# Epoch 14/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9777 - loss: 0.0724
# Epoch 14: val_accuracy did not improve from 0.98242
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9778 - loss: 0.0724 - val_accuracy: 0.9818 - val_loss: 0.0690 - learning_rate: 0.0020
# Epoch 15/100
# 542/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9787 - loss: 0.0729
# Epoch 15: val_accuracy improved from 0.98242 to 0.98252, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9787 - loss: 0.0729 - val_accuracy: 0.9825 - val_loss: 0.0644 - learning_rate: 0.0020
# Epoch 16/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.0716
# Epoch 16: val_accuracy did not improve from 0.98252
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9788 - loss: 0.0716 - val_accuracy: 0.9817 - val_loss: 0.0638 - learning_rate: 0.0020
# Epoch 17/100
# 542/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0678
# Epoch 17: val_accuracy did not improve from 0.98252
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9799 - loss: 0.0678 - val_accuracy: 0.9824 - val_loss: 0.0616 - learning_rate: 0.0020
# Epoch 18/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0687
# Epoch 18: val_accuracy improved from 0.98252 to 0.98272, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9800 - loss: 0.0686 - val_accuracy: 0.9827 - val_loss: 0.0603 - learning_rate: 0.0020
# Epoch 19/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9795 - loss: 0.0661
# Epoch 19: val_accuracy improved from 0.98272 to 0.98291, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9795 - loss: 0.0661 - val_accuracy: 0.9829 - val_loss: 0.0602 - learning_rate: 0.0020
# Epoch 20/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9802 - loss: 0.0667
# Epoch 20: val_accuracy did not improve from 0.98291
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9802 - loss: 0.0667 - val_accuracy: 0.9804 - val_loss: 0.0636 - learning_rate: 0.0020
# Epoch 21/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9807 - loss: 0.0664
# Epoch 21: val_accuracy improved from 0.98291 to 0.98331, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9807 - loss: 0.0664 - val_accuracy: 0.9833 - val_loss: 0.0571 - learning_rate: 0.0020
# Epoch 22/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9818 - loss: 0.0632
# Epoch 22: val_accuracy improved from 0.98331 to 0.98341, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0632 - val_accuracy: 0.9834 - val_loss: 0.0556 - learning_rate: 0.0020
# Epoch 23/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.0650
# Epoch 23: val_accuracy did not improve from 0.98341
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9808 - loss: 0.0650 - val_accuracy: 0.9834 - val_loss: 0.0591 - learning_rate: 0.0020
# Epoch 24/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0633
# Epoch 24: val_accuracy did not improve from 0.98341
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0633 - val_accuracy: 0.9813 - val_loss: 0.0628 - learning_rate: 0.0020
# Epoch 25/100
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0629
# Epoch 25: val_accuracy did not improve from 0.98341
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9812 - loss: 0.0629 - val_accuracy: 0.9824 - val_loss: 0.0581 - learning_rate: 0.0020
# Epoch 26/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9813 - loss: 0.0638
# Epoch 26: val_accuracy did not improve from 0.98341
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9813 - loss: 0.0638 - val_accuracy: 0.9830 - val_loss: 0.0577 - learning_rate: 0.0020
# Epoch 27/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0578
# Epoch 27: val_accuracy improved from 0.98341 to 0.98391, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9824 - loss: 0.0578 - val_accuracy: 0.9839 - val_loss: 0.0549 - learning_rate: 0.0020
# Epoch 28/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.0641
# Epoch 28: val_accuracy improved from 0.98391 to 0.98530, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9808 - loss: 0.0640 - val_accuracy: 0.9853 - val_loss: 0.0540 - learning_rate: 0.0020
# Epoch 29/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9818 - loss: 0.0607
# Epoch 29: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0607 - val_accuracy: 0.9824 - val_loss: 0.0620 - learning_rate: 0.0020
# Epoch 30/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9820 - loss: 0.0599
# Epoch 30: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9820 - loss: 0.0599 - val_accuracy: 0.9841 - val_loss: 0.0536 - learning_rate: 0.0020
# Epoch 31/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9817 - loss: 0.0597
# Epoch 31: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9817 - loss: 0.0597 - val_accuracy: 0.9830 - val_loss: 0.0570 - learning_rate: 0.0020
# Epoch 32/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.0579
# Epoch 32: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9824 - loss: 0.0579 - val_accuracy: 0.9841 - val_loss: 0.0543 - learning_rate: 0.0020
# Epoch 33/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9823 - loss: 0.0583
# Epoch 33: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9823 - loss: 0.0582 - val_accuracy: 0.9847 - val_loss: 0.0509 - learning_rate: 0.0020
# Epoch 34/100
# 548/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9819 - loss: 0.0589
# Epoch 34: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9819 - loss: 0.0588 - val_accuracy: 0.9852 - val_loss: 0.0520 - learning_rate: 0.0020
# Epoch 35/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.0549
# Epoch 35: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9828 - loss: 0.0549 - val_accuracy: 0.9848 - val_loss: 0.0534 - learning_rate: 0.0020
# Epoch 36/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9841 - loss: 0.0553
# Epoch 36: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9841 - loss: 0.0553 - val_accuracy: 0.9820 - val_loss: 0.0581 - learning_rate: 0.0020
# Epoch 37/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9834 - loss: 0.0541
# Epoch 37: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0542 - val_accuracy: 0.9841 - val_loss: 0.0526 - learning_rate: 0.0020
# Epoch 38/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9831 - loss: 0.0547
# Epoch 38: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9831 - loss: 0.0547 - val_accuracy: 0.9845 - val_loss: 0.0562 - learning_rate: 0.0020
# Epoch 39/100
# 536/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9839 - loss: 0.0533
# Epoch 39: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0532 - val_accuracy: 0.9838 - val_loss: 0.0512 - learning_rate: 0.0020
# Epoch 40/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0537
# Epoch 40: val_accuracy did not improve from 0.98530
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0537 - val_accuracy: 0.9843 - val_loss: 0.0496 - learning_rate: 0.0020
# Epoch 41/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0541
# Epoch 41: val_accuracy improved from 0.98530 to 0.98649, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0541 - val_accuracy: 0.9865 - val_loss: 0.0492 - learning_rate: 0.0020
# Epoch 42/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9839 - loss: 0.0519
# Epoch 42: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0519 - val_accuracy: 0.9816 - val_loss: 0.0578 - learning_rate: 0.0020
# Epoch 43/100
# 539/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9830 - loss: 0.0548
# Epoch 43: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9830 - loss: 0.0547 - val_accuracy: 0.9856 - val_loss: 0.0483 - learning_rate: 0.0020
# Epoch 44/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9842 - loss: 0.0525
# Epoch 44: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9842 - loss: 0.0525 - val_accuracy: 0.9824 - val_loss: 0.0566 - learning_rate: 0.0020
# Epoch 45/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9837 - loss: 0.0510
# Epoch 45: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9837 - loss: 0.0510 - val_accuracy: 0.9845 - val_loss: 0.0510 - learning_rate: 0.0020
# Epoch 46/100
# 539/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0494
# Epoch 46: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9846 - loss: 0.0495 - val_accuracy: 0.9857 - val_loss: 0.0488 - learning_rate: 0.0020
# Epoch 47/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9843 - loss: 0.0522
# Epoch 47: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9843 - loss: 0.0522 - val_accuracy: 0.9842 - val_loss: 0.0520 - learning_rate: 0.0020
# Epoch 48/100
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0517
# Epoch 48: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9844 - loss: 0.0517 - val_accuracy: 0.9846 - val_loss: 0.0497 - learning_rate: 0.0020
# Epoch 49/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9838 - loss: 0.0520
# Epoch 49: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0520 - val_accuracy: 0.9854 - val_loss: 0.0481 - learning_rate: 0.0020
# Epoch 50/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0501
# Epoch 50: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9850 - loss: 0.0501 - val_accuracy: 0.9854 - val_loss: 0.0490 - learning_rate: 0.0020
# Epoch 51/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9845 - loss: 0.0507
# Epoch 51: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9845 - loss: 0.0507 - val_accuracy: 0.9855 - val_loss: 0.0476 - learning_rate: 0.0020
# Epoch 52/100
# 536/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9851 - loss: 0.0499
# Epoch 52: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9851 - loss: 0.0499 - val_accuracy: 0.9835 - val_loss: 0.0507 - learning_rate: 0.0020
# Epoch 53/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.0506
# Epoch 53: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9847 - loss: 0.0506 - val_accuracy: 0.9840 - val_loss: 0.0523 - learning_rate: 0.0020
# Epoch 54/100
# 539/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9847 - loss: 0.0494
# Epoch 54: val_accuracy did not improve from 0.98649
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9847 - loss: 0.0494 - val_accuracy: 0.9842 - val_loss: 0.0506 - learning_rate: 0.0020
# Epoch 55/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0501
# Epoch 55: val_accuracy improved from 0.98649 to 0.98738, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9844 - loss: 0.0500 - val_accuracy: 0.9874 - val_loss: 0.0451 - learning_rate: 0.0020
# Epoch 56/100
# 539/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9851 - loss: 0.0479
# Epoch 56: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9851 - loss: 0.0479 - val_accuracy: 0.9868 - val_loss: 0.0453 - learning_rate: 0.0020
# Epoch 57/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9848 - loss: 0.0486
# Epoch 57: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9848 - loss: 0.0486 - val_accuracy: 0.9869 - val_loss: 0.0456 - learning_rate: 0.0020
# Epoch 58/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9853 - loss: 0.0480
# Epoch 58: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9853 - loss: 0.0480 - val_accuracy: 0.9854 - val_loss: 0.0448 - learning_rate: 0.0020
# Epoch 59/100
# 542/551 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9849 - loss: 0.0479
# Epoch 59: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9849 - loss: 0.0479 - val_accuracy: 0.9854 - val_loss: 0.0463 - learning_rate: 0.0020
# Epoch 60/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0486
# Epoch 60: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9850 - loss: 0.0486 - val_accuracy: 0.9855 - val_loss: 0.0470 - learning_rate: 0.0020
# Epoch 61/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0459
# Epoch 61: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9863 - loss: 0.0459 - val_accuracy: 0.9850 - val_loss: 0.0482 - learning_rate: 0.0020
# Epoch 62/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9861 - loss: 0.0466
# Epoch 62: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9861 - loss: 0.0466 - val_accuracy: 0.9873 - val_loss: 0.0447 - learning_rate: 0.0020
# Epoch 63/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9861 - loss: 0.0469
# Epoch 63: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9861 - loss: 0.0469 - val_accuracy: 0.9838 - val_loss: 0.0501 - learning_rate: 0.0020
# Epoch 64/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0454
# Epoch 64: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9860 - loss: 0.0454 - val_accuracy: 0.9854 - val_loss: 0.0465 - learning_rate: 0.0020
# Epoch 65/100
# 546/551 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9858 - loss: 0.0464
# Epoch 65: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9858 - loss: 0.0464 - val_accuracy: 0.9861 - val_loss: 0.0468 - learning_rate: 0.0020
# Epoch 66/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.0461
# Epoch 66: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9858 - loss: 0.0461 - val_accuracy: 0.9847 - val_loss: 0.0491 - learning_rate: 0.0020
# Epoch 67/100
# 547/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0460
# Epoch 67: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9862 - loss: 0.0460 - val_accuracy: 0.9839 - val_loss: 0.0511 - learning_rate: 0.0020
# Epoch 68/100
# 547/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9856 - loss: 0.0473
# Epoch 68: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9856 - loss: 0.0472 - val_accuracy: 0.9845 - val_loss: 0.0492 - learning_rate: 0.0020
# Epoch 69/100
# 548/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9852 - loss: 0.0465
# Epoch 69: val_accuracy did not improve from 0.98738
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9852 - loss: 0.0465 - val_accuracy: 0.9856 - val_loss: 0.0488 - learning_rate: 0.0020
# Epoch 70/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0466
# Epoch 70: val_accuracy improved from 0.98738 to 0.98788, saving model to baseline_ecg_transformer.weights.h5
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9863 - loss: 0.0466 - val_accuracy: 0.9879 - val_loss: 0.0435 - learning_rate: 0.0020
# Epoch 71/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0439
# Epoch 71: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9860 - loss: 0.0439 - val_accuracy: 0.9871 - val_loss: 0.0433 - learning_rate: 0.0020
# Epoch 72/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9854 - loss: 0.0451
# Epoch 72: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9854 - loss: 0.0452 - val_accuracy: 0.9868 - val_loss: 0.0448 - learning_rate: 0.0020
# Epoch 73/100
# 550/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9866 - loss: 0.0447
# Epoch 73: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9866 - loss: 0.0447 - val_accuracy: 0.9867 - val_loss: 0.0454 - learning_rate: 0.0020
# Epoch 74/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9866 - loss: 0.0436
# Epoch 74: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9866 - loss: 0.0437 - val_accuracy: 0.9853 - val_loss: 0.0490 - learning_rate: 0.0020
# Epoch 75/100
# 537/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9864 - loss: 0.0448
# Epoch 75: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9864 - loss: 0.0447 - val_accuracy: 0.9868 - val_loss: 0.0453 - learning_rate: 0.0020
# Epoch 76/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9869 - loss: 0.0430
# Epoch 76: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9869 - loss: 0.0430 - val_accuracy: 0.9877 - val_loss: 0.0444 - learning_rate: 0.0020
# Epoch 77/100
# 543/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9867 - loss: 0.0449
# Epoch 77: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9867 - loss: 0.0449 - val_accuracy: 0.9842 - val_loss: 0.0491 - learning_rate: 0.0020
# Epoch 78/100
# 538/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9855 - loss: 0.0455
# Epoch 78: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9855 - loss: 0.0454 - val_accuracy: 0.9854 - val_loss: 0.0483 - learning_rate: 0.0020
# Epoch 79/100
# 547/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9869 - loss: 0.0435
# Epoch 79: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9869 - loss: 0.0435 - val_accuracy: 0.9860 - val_loss: 0.0439 - learning_rate: 0.0020
# Epoch 80/100
# 542/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.0424
# Epoch 80: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9873 - loss: 0.0424 - val_accuracy: 0.9853 - val_loss: 0.0482 - learning_rate: 0.0020
# Epoch 81/100
# 550/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9867 - loss: 0.0437
# Epoch 81: val_accuracy did not improve from 0.98788
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9867 - loss: 0.0437 - val_accuracy: 0.9867 - val_loss: 0.0469 - learning_rate: 0.0020
# Epoch 82/100
# 550/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9872 - loss: 0.0410
# Epoch 82: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9872 - loss: 0.0410 - val_accuracy: 0.9874 - val_loss: 0.0427 - learning_rate: 0.0010
# Epoch 83/100
# 541/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9878 - loss: 0.0389
# Epoch 83: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9878 - loss: 0.0389 - val_accuracy: 0.9876 - val_loss: 0.0400 - learning_rate: 0.0010
# Epoch 84/100
# 540/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9875 - loss: 0.0394
# Epoch 84: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9875 - loss: 0.0393 - val_accuracy: 0.9868 - val_loss: 0.0424 - learning_rate: 0.0010
# Epoch 85/100
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9875 - loss: 0.0383
# Epoch 85: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9875 - loss: 0.0383 - val_accuracy: 0.9874 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 86/100
# 536/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0387
# Epoch 86: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9878 - loss: 0.0387 - val_accuracy: 0.9874 - val_loss: 0.0435 - learning_rate: 0.0010
# Epoch 87/100
# 547/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9882 - loss: 0.0380
# Epoch 87: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9882 - loss: 0.0380 - val_accuracy: 0.9867 - val_loss: 0.0437 - learning_rate: 0.0010
# Epoch 88/100
# 544/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9893 - loss: 0.0367
# Epoch 88: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9893 - loss: 0.0367 - val_accuracy: 0.9862 - val_loss: 0.0462 - learning_rate: 0.0010
# Epoch 89/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0359
# Epoch 89: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9885 - loss: 0.0359 - val_accuracy: 0.9866 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 90/100
# 536/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9878 - loss: 0.0402
# Epoch 90: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9878 - loss: 0.0401 - val_accuracy: 0.9868 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 91/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0376
# Epoch 91: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9885 - loss: 0.0376 - val_accuracy: 0.9869 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 92/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0378
# Epoch 92: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9885 - loss: 0.0378 - val_accuracy: 0.9867 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 93/100
# 548/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0377
# Epoch 93: val_accuracy did not improve from 0.98788
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9886 - loss: 0.0377 - val_accuracy: 0.9875 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 94/100
# 545/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.0346
# Epoch 94: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9892 - loss: 0.0346 - val_accuracy: 0.9873 - val_loss: 0.0413 - learning_rate: 5.0000e-04
# Epoch 95/100
# 549/551 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.0340
# Epoch 95: val_accuracy did not improve from 0.98788
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9896 - loss: 0.0340 - val_accuracy: 0.9877 - val_loss: 0.0426 - learning_rate: 5.0000e-04
# Epoch 95: early stopping
# Restoring model weights from the end of the best epoch: 70.
# ✅ Baseline training completed!
# Best validation accuracy: 0.9879
#
# 📊 Evaluating Baseline Model...
#
# 🧪 Evaluating Baseline Model...
# Running inference...
#   Processed 10 batches...
#   Processed 20 batches...
#   Processed 30 batches...
#   Processed 40 batches...
#   Processed 50 batches...
#   Processed 60 batches...
#   Processed 70 batches...
#   Processed 80 batches...
#   Processed 90 batches...
#   Processed 100 batches...
#   Processed 110 batches...
#   Processed 120 batches...
#   Processed 130 batches...
#   Processed 140 batches...
#   Processed 150 batches...
#
# 📊 Baseline Model Test Results:
# Test Loss:           0.0403
# Test Accuracy:       0.9883
# Precision (macro):   0.7525
# Recall (macro):      0.7142
# F1-Score (macro):    0.7322
# Precision (weighted): 0.9879
# Recall (weighted):   0.9883
# F1-Score (weighted): 0.9880
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#            N     0.9922    0.9966    0.9944     18015
#            S     0.9517    0.8507    0.8984       556
#            V     0.9657    0.9657    0.9657      1401
#            F     0.8531    0.7578    0.8026       161
#            Q     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.9883     20136
#    macro avg     0.7525    0.7142    0.7322     20136
# weighted avg     0.9879    0.9883    0.9880     20136
#
# 💾 Results saved to baseline_results.json
#
# 📈 Generating training history plot...
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📈 Generating confusion matrix...
# ============================================================
# 🎉 BASELINE MODEL SUMMARY
# ============================================================
# Test Accuracy:     0.9883
# Test Loss:         0.0403
# F1-Score (macro):  0.7322
# F1-Score (weighted): 0.9880
#
# 💾 Files Generated:
#   - baseline_ecg_transformer.weights.h5 (model weights)
#   - baseline_results.json (detailed results)
#   - consistent_data_splits.npz (data splits for consistency)
#   - baseline_training_history.png
#   - baseline_confusion_matrix.png
#
# ✅ Baseline model training and evaluation completed!
# 📋 This baseline will be used for comparison with the dynamic model.

# %% [markdown]
# ---------------------------------------------------------------------------
